# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
# Out:
# /home/florian/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'originated', 'term', 'anarchism', 'of', 'term', 'as', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.871839
# Nearest to no: concocted, indicate, appendages, eno, platte, always, irritation, forensic,
# Nearest to an: equaled, retro, charlemagne, conjunctions, finds, millikan, exemplify, otaku,
# Nearest to only: rg, xs, elicit, huac, nearby, asimov, turku, qaida,
# Nearest to he: hypertension, defective, zbigniew, alcuin, montage, buys, goncourt, website,
# Nearest to such: allowed, alliaceae, panavia, sovereigns, crick, spectrometers, corwin, fairgrounds,
# Nearest to but: sedimentary, excluding, overlook, nicolaus, fanaticism, concealment, hartman, meccans,
# Nearest to which: nomenclature, palace, eg, bamiyan, pfa, milo, illuminatus, ribose,
# Nearest to over: homeopaths, silicone, ivor, wade, icon, texan, xii, pln,
# Nearest to united: cryopreserved, mont, immigration, irregularity, notional, pfp, rq, darker,
# Nearest to six: buridan, epics, unspoken, borrowings, borderlands, numerous, alkaloids, reiner,
# Nearest to time: janos, nyasa, likened, gazetteer, druze, wheelchair, careful, deciduous,
# Nearest to was: newborns, atanasoff, cement, inalienable, alloy, literary, bayreuth, faire,
# Nearest to first: achaemenid, pk, angel, castes, fought, atone, gainesville, egyptians,
# Nearest to are: fundy, immortals, resolution, existent, alexandrine, continuation, tasking, bodied,
# Nearest to these: redirection, restricting, lakota, bletchley, manx, vandal, buber, politically,
# Nearest to by: fray, melos, inadvertently, gygax, musician, morpork, palacio, impression,
# Average loss at step 2000: 4.372945
# Average loss at step 4000: 3.865631
# Average loss at step 6000: 3.784262
# Average loss at step 8000: 3.692289
# Average loss at step 10000: 3.617700
# Nearest to no: always, concocted, it, nominated, indicate, killed, appendages, hesitated,
# Nearest to an: the, retro, otaku, charlemagne, vanzetti, lassen, heisei, personages,
# Nearest to only: huac, rg, codebase, texas, nearby, guadalupe, clothing, urgell,
# Nearest to he: it, they, who, she, there, deities, never, attractors,
# Nearest to such: allowed, well, corwin, lease, maid, microsite, unclear, sovereigns,
# Nearest to but: meccans, though, excluding, has, avian, champions, nonviolence, fanaticism,
# Nearest to which: that, also, this, datum, it, syndicates, appian, consulate,
# Nearest to over: effects, puts, dido, cretian, toolkit, nearly, kilometers, icon,
# Nearest to united: cryopreserved, compl, filking, hewlett, alsace, causation, sabha, candler,
# Nearest to six: seven, eight, five, four, three, nine, zero, two,
# Nearest to time: janos, careful, tats, expanses, arguably, whewell, likened, race,
# Nearest to was: is, has, had, were, be, by, are, angola,
# Nearest to first: second, achaemenid, greenland, angel, benefit, muonium, most, exact,
# Nearest to are: were, is, have, was, fundy, kimberly, cfb, ark,
# Nearest to these: redirection, swimmer, bletchley, restricting, handball, commensurate, operation, sampras,
# Nearest to by: inadvertently, fray, was, in, tipped, stable, graduated, been,
# Average loss at step 12000: 3.611300
# Average loss at step 14000: 3.575322
# Average loss at step 16000: 3.409331
# Average loss at step 18000: 3.456085
# Average loss at step 20000: 3.540598
# Nearest to no: always, nominated, killed, concocted, a, only, kaua, substantial,
# Nearest to an: retro, the, otaku, charlemagne, rotors, lassen, pdf, conjunctions,
# Nearest to only: alcuin, codebase, guadalupe, butlerian, huac, no, cached, it,
# Nearest to he: it, she, they, who, there, deities, tsvetaeva, never,
# Nearest to such: well, allowed, known, these, antoinette, legalistic, issues, lease,
# Nearest to but: though, however, which, and, now, matheson, that, usually,
# Nearest to which: this, that, also, but, it, these, who, perpetrator,
# Nearest to over: effects, dido, cretian, nearly, toolkit, silicone, philo, potent,
# Nearest to united: cryopreserved, hewlett, sabha, compl, notional, wasteful, causation, alsace,
# Nearest to six: seven, eight, three, five, nine, four, two, zero,
# Nearest to time: year, rainbows, arguably, results, cretian, expanses, tats, lifeson,
# Nearest to was: is, were, has, had, be, are, been, became,
# Nearest to first: second, greenland, angel, muonium, achaemenid, egyptians, traditional, ready,
# Nearest to are: were, is, have, was, cfb, contractile, annuity, although,
# Nearest to these: some, many, several, which, other, jit, all, redirection,
# Nearest to by: in, into, have, with, be, solicitors, multi, bishoprics,
# Average loss at step 22000: 3.503106
# Average loss at step 24000: 3.491178
# Average loss at step 26000: 3.480718
# Average loss at step 28000: 3.481766
# Average loss at step 30000: 3.503404
# Nearest to no: always, any, a, only, latinized, nominated, substantial, killed,
# Nearest to an: otaku, retro, venus, rotors, cellos, charlemagne, equaled, supergroup,
# Nearest to only: wco, no, clothing, cached, primarily, corpses, alcuin, represents,
# Nearest to he: it, she, they, who, there, haas, deities, murmur,
# Nearest to such: well, these, antoinette, known, other, legalistic, issues, regnant,
# Nearest to but: however, and, though, although, while, which, yet, where,
# Nearest to which: this, that, also, what, but, who, it, rampart,
# Nearest to over: philo, dido, nearly, effects, toolkit, potent, murderers, vein,
# Nearest to united: cryopreserved, compl, sabha, hewlett, notional, stockpiling, paratime, causation,
# Nearest to six: four, eight, five, seven, nine, three, two, zero,
# Nearest to time: year, place, auden, rainbows, galleria, lasted, results, refracted,
# Nearest to was: is, were, has, had, been, became, by, be,
# Nearest to first: second, last, greenland, angel, surreal, original, muonium, egyptians,
# Nearest to are: were, is, have, include, these, although, polyphonic, annuity,
# Nearest to these: some, many, they, such, several, their, other, all,
# Nearest to by: with, in, was, under, from, wels, during, multi,
# Average loss at step 32000: 3.499698
# Average loss at step 34000: 3.491254
# Average loss at step 36000: 3.456308
# Average loss at step 38000: 3.298229
# Average loss at step 40000: 3.430432
# Nearest to no: any, always, than, only, substantial, latinized, a, forensic,
# Nearest to an: otaku, charlemagne, retro, stench, lassen, venus, the, cellos,
# Nearest to only: palacio, no, codebase, it, wco, needed, cached, either,
# Nearest to he: it, she, they, who, there, later, tsvetaeva, i,
# Nearest to such: well, these, known, including, antoinette, unionists, many, tangible,
# Nearest to but: however, though, and, although, while, it, which, youssef,
# Nearest to which: that, this, also, what, it, who, usually, often,
# Nearest to over: into, nearly, savages, toolkit, dido, about, tainted, guardian,
# Nearest to united: cryopreserved, compl, hewlett, student, sabha, notional, vre, stockpiling,
# Nearest to six: seven, four, eight, five, nine, three, two, zero,
# Nearest to time: year, arguably, place, way, period, lasted, reprimanded, reassert,
# Nearest to was: is, had, has, were, became, been, be, when,
# Nearest to first: second, last, next, greenland, angel, egyptians, surreal, viscous,
# Nearest to are: were, have, include, is, kimberly, beads, be, although,
# Nearest to these: some, many, they, several, such, different, jit, including,
# Nearest to by: be, when, as, with, multi, into, boulez, encampment,
# Average loss at step 42000: 3.438233
# Average loss at step 44000: 3.453259
# Average loss at step 46000: 3.448263
# Average loss at step 48000: 3.355540
# Average loss at step 50000: 3.382715
# Nearest to no: any, always, latinized, little, substantial, sanjo, only, than,
# Nearest to an: otaku, cellos, retro, mujahideen, venus, conjunctions, bigotry, boers,
# Nearest to only: always, all, codebase, exclaves, downloaded, represents, palacio, gunman,
# Nearest to he: she, it, they, there, who, we, tsvetaeva, uvular,
# Nearest to such: well, these, known, many, including, antoinette, protestors, clerks,
# Nearest to but: however, though, although, while, when, during, and, that,
# Nearest to which: this, that, what, also, who, often, usually, decca,
# Nearest to over: on, about, nearly, savages, zodiacal, around, guardian, propel,
# Nearest to united: cryopreserved, student, compl, sabha, stockpiling, notional, hewlett, census,
# Nearest to six: eight, seven, four, nine, three, five, two, zero,
# Nearest to time: year, period, way, place, kind, arguably, night, feet,
# Nearest to was: is, were, has, became, had, be, been, being,
# Nearest to first: last, second, next, greenland, bargain, nba, arab, following,
# Nearest to are: were, is, have, kimberly, those, be, include, was,
# Nearest to these: some, many, several, such, both, they, those, certain,
# Nearest to by: under, was, in, through, multi, during, with, hylas,
# Average loss at step 52000: 3.436645
# Average loss at step 54000: 3.425130
# Average loss at step 56000: 3.440603
# Average loss at step 58000: 3.396952
# Average loss at step 60000: 3.394013
# Nearest to no: any, little, always, only, extensive, latinized, dislikes, lilly,
# Nearest to an: cellos, lassen, duelling, stench, charlemagne, retro, conjunctions, boers,
# Nearest to only: always, actually, palacio, no, downloaded, either, florid, never,
# Nearest to he: she, it, they, who, there, we, tsvetaeva, later,
# Nearest to such: these, known, well, many, including, antoinette, clerks, certain,
# Nearest to but: however, although, and, though, while, see, when, which,
# Nearest to which: that, this, what, who, it, however, challenger, there,
# Nearest to over: dido, savages, nearly, around, within, about, coslet, kroon,
# Nearest to united: cryopreserved, senate, stockpiling, notional, student, census, compl, cante,
# Nearest to six: four, eight, nine, five, seven, three, two, one,
# Nearest to time: year, period, place, way, arguably, kind, donny, results,
# Nearest to was: is, had, became, were, has, be, been, although,
# Nearest to first: last, second, next, same, third, following, beauvoir, desolation,
# Nearest to are: were, is, have, include, be, kimberly, those, although,
# Nearest to these: many, several, some, those, such, they, both, certain,
# Nearest to by: under, through, with, commutators, fiefs, fuelled, using, hurdles,
# Average loss at step 62000: 3.243500
# Average loss at step 64000: 3.251518
# Average loss at step 66000: 3.407529
# Average loss at step 68000: 3.394512
# Average loss at step 70000: 3.357205
# Nearest to no: little, any, extensive, always, substantial, endpin, there, sanjo,
# Nearest to an: conjunctions, cellos, the, retro, lassen, stench, bigotry, otaku,
# Nearest to only: always, either, actually, never, nor, gunman, downloaded, no,
# Nearest to he: she, it, they, there, who, uvular, originally, we,
# Nearest to such: these, well, known, many, being, including, certain, dubious,
# Nearest to but: however, though, although, which, and, that, while, stuka,
# Nearest to which: that, this, what, also, but, usually, often, decca,
# Nearest to over: about, savages, within, around, kroon, nearly, dido, poorer,
# Nearest to united: stockpiling, same, census, senate, student, notional, cante, cryopreserved,
# Nearest to six: eight, four, seven, nine, five, three, two, zero,
# Nearest to time: arguably, year, place, kind, period, way, rule, issue,
# Nearest to was: is, has, had, were, became, been, be, when,
# Nearest to first: second, last, next, same, original, third, beauvoir, sandworm,
# Nearest to are: were, is, include, have, kimberly, although, be, these,
# Nearest to these: some, many, such, several, those, their, unspoken, certain,
# Nearest to by: through, furnishing, be, in, barak, using, boulez, flavour,
# Average loss at step 72000: 3.374088
# Average loss at step 74000: 3.349327
# Average loss at step 76000: 3.316599
# Average loss at step 78000: 3.354314
# Average loss at step 80000: 3.381739
# Nearest to no: little, any, manna, exceptional, harpo, kaua, extensive, endpin,
# Nearest to an: venus, charlemagne, retro, vanzetti, lassen, duelling, otaku, mujahideen,
# Nearest to only: always, actually, either, greenaway, finely, therefore, downloaded, strangers,
# Nearest to he: she, it, they, there, who, uvular, we, originally,
# Nearest to such: well, these, known, certain, follows, including, described, many,
# Nearest to but: however, although, while, and, though, or, see, than,
# Nearest to which: this, that, usually, often, also, based, what, these,
# Nearest to over: around, within, about, savages, into, across, nearly, through,
# Nearest to united: stockpiling, same, census, senate, student, constitution, notional, cante,
# Nearest to six: seven, five, eight, four, three, nine, two, one,
# Nearest to time: year, arguably, period, place, kind, issue, event, rule,
# Nearest to was: is, became, has, had, were, cnr, be, hutcheson,
# Nearest to first: second, last, next, same, third, final, desolation, sandworm,
# Nearest to are: were, is, have, include, although, presheaf, kimberly, those,
# Nearest to these: several, some, many, those, such, both, certain, various,
# Nearest to by: when, through, using, assaulting, hurdles, clu, yun, yahya,
# Average loss at step 82000: 3.407837
# Average loss at step 84000: 3.407812
# Average loss at step 86000: 3.394680
# Average loss at step 88000: 3.351352
# Average loss at step 90000: 3.366901
# Nearest to no: little, any, only, always, extensive, lilly, sanjo, manna,
# Nearest to an: venus, cellos, retro, charlemagne, huckleberry, supergroup, mujahideen, stench,
# Nearest to only: always, actually, no, either, therefore, ssris, greenaway, necessarily,
# Nearest to he: she, it, they, there, who, uvular, originally, later,
# Nearest to such: well, known, these, follows, described, certain, opposed, regarded,
# Nearest to but: however, although, and, while, though, she, they, until,
# Nearest to which: what, this, that, usually, also, who, typically, often,
# Nearest to over: around, about, within, nearly, across, through, savages, goebbels,
# Nearest to united: same, constitution, senate, stockpiling, notional, cante, baltic, census,
# Nearest to six: seven, eight, five, four, nine, three, two, zero,
# Nearest to time: period, year, arguably, wat, reprisal, event, kind, precipitous,
# Nearest to was: is, became, had, were, has, be, been, being,
# Nearest to first: last, second, third, next, same, final, sandworm, desolation,
# Nearest to are: were, is, include, have, although, these, kimberly, beads,
# Nearest to these: several, some, many, those, unspoken, such, certain, various,
# Nearest to by: when, through, with, while, using, norodom, yahya, under,
# Average loss at step 92000: 3.400525
# Average loss at step 94000: 3.253909
# Average loss at step 96000: 3.356145
# Average loss at step 98000: 3.242886
# Average loss at step 100000: 3.351601
# Nearest to no: little, any, only, always, lilly, rumour, extensive, manna,
# Nearest to an: huckleberry, conjunctions, mujahideen, charlemagne, retro, cellos, unconditional, stench,
# Nearest to only: actually, always, no, never, either, palacio, necessarily, rulemaking,
# Nearest to he: she, it, they, there, who, we, never, uvular,
# Nearest to such: well, these, known, many, follows, dubious, described, certain,
# Nearest to but: although, however, and, while, though, which, that, satisfies,
# Nearest to which: that, this, usually, what, but, these, typically, often,
# Nearest to over: around, nearly, about, coslet, across, into, within, vein,
# Nearest to united: same, constitution, senate, census, baltic, cante, stockpiling, notional,
# Nearest to six: seven, four, five, eight, nine, three, two, zero,
# Nearest to time: year, way, kind, period, arguably, reprisal, kiwi, place,
# Nearest to was: is, became, had, has, were, been, mohandas, while,
# Nearest to first: last, second, next, third, same, final, fourth, beauvoir,
# Nearest to are: were, have, although, is, include, these, be, while,
# Nearest to these: several, many, some, those, various, certain, multiple, such,
# Nearest to by: when, through, barak, under, caviar, using, during, with,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
