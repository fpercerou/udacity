# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils
# Out:
# /home/florian/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:50, 616kB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
# vocab_to_int: vocab to int dictionary
# int_to_vocab: list of size of words where words have been replaced by corresponding int
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
import random
import collections

threshold = 1e-5

nb_words = len(int_words)
counter = collections.Counter(int_words)
word_freq = {i: float(c) / float(nb_words) for i, c in counter.items()}

train_words = [w for w in int_words
               if random.random() > (1 - np.sqrt(threshold / word_freq[w]))]

# %%
print("Proba of removing 'the':", 1 - np.sqrt(threshold / word_freq[vocab_to_int['the']]))
print("Proba of removing 'elephant':", 1 - np.sqrt(threshold / word_freq[vocab_to_int['elephant']]))
# Out:
# Proba of removing 'the': 0.9874637657774047
# Proba of removing 'elephant': 0.2711452356498425

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    window_size_random = random.randint(1, window_size)
    start = idx - window_size_random if (idx - window_size_random) > 0 else 0
    end = ((idx + window_size_random + 1) if (idx + window_size_random + 1) > (len(words) - 1)
           else (len(words) - 1)) 
    
    return list(set(words[start: idx] + words[(idx + 1): start]))

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            # for each word in the batch, adding the word and it corresponding context
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, shape=[None], name='inputs') # shape=None to get more flexibility
    labels = tf.placeholder(tf.int32, shape=[None, 1], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.truncated_normal(shape = [n_vocab, n_embedding],
                                                mean=0.0,
                                                stddev=0.1),
                            name='embedding_matrix') # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(params=embedding,
                                   ids=inputs) # use tf.nn.embedding_lookup to get the hidden layer output
    
    # Notes:
    # Alternatively one could also return 
    # tf.contrib.layers.embed_sequence(input_data, vocab_size, embed_dim).
    # One can read more about this function
    # here: https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal(shape = [n_vocab, n_embedding],
                                                mean=0.0,
                                                stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.truncated_normal(shape = [n_vocab],
                                                mean=0.0,
                                                stddev=0.1)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(weights=softmax_w,
                                      biases=softmax_b,
                                      labels=labels,
                                      inputs=embed,
                                      num_sampled=n_sampled,
                                      num_classes=n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost) # default learning rate here

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-62-2aa168c49a56>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        iteration = 1
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 10 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100),
                      end='\r')
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                print("")
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
                print("\n\n")
            
            iteration += 1
        print("")
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 0.4975 0.0128 sec/batch
# Nearest to zero: three, to, eight, but, was, at, four, six,
# Nearest to over: this, as, on, band, for, no, he, second,
# Nearest to six: two, one, seven, five, new, four, three, zero,
# Nearest to there: he, new, in, and, up, has, until, the,
# Nearest to however: time, both, to, over, as, it, they, british,
# Nearest to these: until, and, its, up, who, called, in, history,
# Nearest to most: and, to, as, great, up, below, is, zero,
# Nearest to states: and, seven, he, have, as, also, three, their,
# Nearest to report: no, national, for, different, merged, way, finally, why,
# Nearest to writers: could, remained, seven, centre, eight, early, would, south,
# Nearest to engineering: since, confirmed, london, more, still, libraries, huge, soon,
# Nearest to applications: build, something, had, out, fly, is, their, have,
# Nearest to placed: but, sometimes, was, not, million, between, people, like,
# Nearest to articles: united, with, all, company, this, s, since, each,
# Nearest to numerous: took, early, eight, after, known, united, album, people,
# Nearest to taking: official, on, e, and, where, from, as, although,
#
#
#
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 0.4689 0.0145 sec/batch
# Nearest to zero: three, four, six, five, seven, eight, one, two,
# Nearest to over: as, form, important, going, intensive, of, this, actual,
# Nearest to six: one, four, two, seven, eight, five, three, nine,
# Nearest to there: problem, traditional, for, guidelines, embedded, understood, the, of,
# Nearest to however: both, to, descriptive, previous, over, as, the, inner,
# Nearest to these: knowledge, our, interested, important, larger, produce, thus, suitable,
# Nearest to most: and, to, as, inside, the, where, person, equal,
# Nearest to states: central, allowed, and, kingdom, independence, member, great, troops,
# Nearest to report: landlocked, intervene, winds, national, attracted, candidate, interaction, obligations,
# Nearest to writers: immigrants, remaining, interpret, prepare, ireland, believed, mainly, national,
# Nearest to engineering: perfectly, confirmed, impossible, libraries, labor, protected, ink, millions,
# Nearest to applications: systems, analog, is, have, standards, value, if, stored,
# Nearest to placed: sometimes, but, experience, ensure, travel, approached, this, not,
# Nearest to articles: fossilized, whether, arguments, all, think, followers, favour, parliamentary,
# Nearest to numerous: towns, influx, trend, outside, early, native, obsolete, exceed,
# Nearest to taking: persons, convention, chinese, although, on, toll, views, rock,
#
#
#
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 0.4683 0.0141 sec/batch
# Nearest to zero: three, five, four, six, two, eight, one, seven,
# Nearest to over: important, of, for, actual, on, traveling, influential, and,
# Nearest to six: four, two, five, eight, seven, one, three, zero,
# Nearest to there: it, their, cases, important, but, has, and, many,
# Nearest to however: both, to, it, but, they, made, previous, time,
# Nearest to these: very, this, ways, such, larger, our, other, used,
# Nearest to most: and, to, as, it, way, many, a, are,
# Nearest to states: kingdom, political, central, nations, territories, northern, presidential, member,
# Nearest to report: landlocked, grounded, popularly, deny, legislatures, date, almanac, handful,
# Nearest to writers: singer, john, natives, wilson, biography, writer, founder, poets,
# Nearest to engineering: perfectly, hazard, beta, convolutions, measurement, constraint, ink, systems,
# Nearest to applications: systems, data, stored, operating, object, user, value, system,
# Nearest to placed: but, sometimes, like, assign, long, this, reliably, it,
# Nearest to articles: amend, contributions, fossilized, comprehensive, dream, neglecting, coverage, advocacy,
# Nearest to numerous: role, influx, took, confiscated, outside, oppression, were, towns,
# Nearest to taking: the, previously, imagining, their, came, thousand, luke, public,
#
#
#
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 0.4376 0.0138 sec/batch
# Nearest to zero: three, four, two, five, six, one, eight, seven,
# Nearest to over: of, for, in, the, combined, important, on, since,
# Nearest to six: four, two, eight, one, three, five, seven, zero,
# Nearest to there: it, of, the, some, has, strongest, between, most,
# Nearest to however: to, were, some, they, it, both, the, especially,
# Nearest to these: very, or, such, this, different, than, often, form,
# Nearest to most: and, as, it, the, in, many, from, other,
# Nearest to states: member, government, nations, political, kingdom, united, representatives, elections,
# Nearest to report: national, official, civilian, sassanian, free, ratifies, merged, woodrow,
# Nearest to writers: autodidacts, poets, novelists, john, story, author, literary, clarke,
# Nearest to engineering: operators, digital, convolutions, electronic, libraries, networks, lossless, technologies,
# Nearest to applications: systems, data, operating, implementations, protocols, stored, user, proprietary,
# Nearest to placed: but, sometimes, than, having, like, it, ascribed, except,
# Nearest to articles: contributions, amend, advocacy, bibles, news, page, history, duly,
# Nearest to numerous: were, resulted, inhabitants, in, outside, persecution, known, early,
# Nearest to taking: came, on, from, the, although, he, re, after,
#
#
#
# Epoch 1/10 Iteration: 4620 Avg. Training loss: 0.4388 0.0137 sec/batch
# Epoch 2/10 Iteration: 1000 Avg. Training loss: 0.4426 0.0141 sec/batch
# Nearest to zero: four, three, two, five, six, eight, one, seven,
# Nearest to over: however, in, years, for, under, rank, increasing, of,
# Nearest to six: four, two, eight, seven, three, one, five, zero,
# Nearest to there: millennium, still, traditional, in, between, and, it, however,
# Nearest to however: both, to, some, were, as, they, over, there,
# Nearest to these: very, such, thus, than, prevalent, significantly, extent, some,
# Nearest to most: and, as, many, in, the, still, from, have,
# Nearest to states: nations, united, political, government, labour, organisations, democratic, federal,
# Nearest to report: international, projects, national, employees, project, february, free, news,
# Nearest to writers: novelists, poets, prose, poetry, autodidacts, literature, literary, books,
# Nearest to engineering: technology, technologies, engineers, systems, digital, networks, management, encoding,
# Nearest to applications: functionality, desktop, stored, systems, tools, architectures, implementations, proprietary,
# Nearest to placed: but, never, so, like, sometimes, leave, not, ascribed,
# Nearest to articles: org, comprehensive, news, page, forum, discussion, publishing, wikipedia,
# Nearest to numerous: towns, outside, pre, influx, villages, been, including, part,
# Nearest to taking: came, own, their, challenge, they, lose, he, would,
#
#
#
# Epoch 2/10 Iteration: 2000 Avg. Training loss: 0.4308 0.0138 sec/batch
# Nearest to zero: four, five, three, two, six, one, eight, seven,
# Nearest to over: challenges, combined, rate, years, less, however, higher, of,
# Nearest to six: four, eight, two, one, five, three, zero, seven,
# Nearest to there: are, other, still, correspond, given, it, some, for,
# Nearest to however: both, to, as, some, for, the, were, time,
# Nearest to these: prevalent, such, distinctions, normative, those, significantly, important, differing,
# Nearest to most: and, are, many, other, as, or, these, prevalent,
# Nearest to states: nations, united, organisations, multilateral, departments, finance, member, democratic,
# Nearest to report: international, research, agency, employees, development, national, free, projects,
# Nearest to writers: novelists, poets, autodidacts, poetry, literary, fiction, essays, literature,
# Nearest to engineering: engineers, technology, management, research, technologies, undergraduate, resource, systems,
# Nearest to applications: desktop, stored, architectures, implementations, systems, operating, functionality, optimized,
# Nearest to placed: but, so, never, attached, moment, fill, cytoplasmic, vibrate,
# Nearest to articles: page, comprehensive, online, org, information, web, discussion, http,
# Nearest to numerous: influx, towns, outside, fishing, metropolis, including, majuro, especially,
# Nearest to taking: lose, own, they, came, would, challenge, their, got,
# Epoch 2/10 Iteration: 3000 Avg. Training loss: 0.4287 0.0140 sec/batch
# Nearest to zero: five, three, four, two, six, eight, one, est,
# Nearest to over: years, rate, total, expectancy, est, challenges, for, of,
# Nearest to six: four, two, five, eight, three, zero, seven, one,
# Nearest to there: are, is, every, given, the, still, it, all,
# Nearest to however: to, both, were, the, for, some, as, time,
# Nearest to these: prevalent, distinctions, certain, distinction, completely, significantly, very, ascertain,
# Nearest to most: and, many, other, relationships, prevalent, are, forms, among,
# Nearest to states: nations, united, organisations, departments, member, presidential, federation, delegate,
# Nearest to report: international, research, employees, projects, agency, investigation, development, free,
# Nearest to writers: novelists, autodidacts, poets, dramatists, fellows, literature, literary, fiction,
# Nearest to engineering: engineers, technology, undergraduate, research, management, electronics, modelling, dynamics,
# Nearest to applications: desktop, stored, optimized, tools, architectures, java, functionality, mainframes,
# Nearest to placed: but, finally, immediately, lengthened, fist, pouch, either, varnish,
# Nearest to articles: page, online, org, faq, html, wiki, comprehensive, com,
# Nearest to numerous: influx, bujumbura, tyre, towns, villages, majuro, famines, role,
# Nearest to taking: they, own, lose, challenge, situation, came, trying, wanted,
#
#
#
# Epoch 2/10 Iteration: 4000 Avg. Training loss: 0.4068 0.0140 sec/batch
# Nearest to zero: two, five, four, six, three, one, eight, est,
# Nearest to over: years, total, rate, of, male, est, under, in,
# Nearest to six: four, five, two, eight, seven, one, three, zero,
# Nearest to there: from, all, the, are, is, greater, egypt, it,
# Nearest to however: to, were, in, for, as, both, some, proscribed,
# Nearest to these: prevalent, very, distinctions, certain, it, ethos, especially, completely,
# Nearest to most: diverse, cultural, many, and, other, prevalent, in, among,
# Nearest to states: nations, united, multilateral, member, delegate, departments, federal, parliaments,
# Nearest to report: international, investigation, agency, research, security, reports, citing, petition,
# Nearest to writers: novelists, autodidacts, poets, dramatists, polymaths, fellows, natives, authors,
# Nearest to engineering: engineers, technology, undergraduate, research, sciences, institute, university, management,
# Nearest to applications: desktop, mainframes, systems, widget, operating, optimized, stored, microsoft,
# Nearest to placed: but, finally, instead, puebla, attached, immediately, unprepared, maldivian,
# Nearest to articles: page, org, online, comprehensive, information, wikipedia, forums, http,
# Nearest to numerous: influx, majuro, maghreb, bujumbura, particularly, outside, pre, including,
# Nearest to taking: lose, would, hurting, wanted, what, they, own, situation,
#
#
#
# Epoch 2/10 Iteration: 4620 Avg. Training loss: 0.4206 0.0138 sec/batch
# Epoch 3/10 Iteration: 1000 Avg. Training loss: 0.4149 0.0136 sec/batch
# Nearest to zero: three, four, two, five, six, eight, one, seven,
# Nearest to over: all, years, challenges, total, est, rank, under, in,
# Nearest to six: five, two, four, eight, three, one, seven, zero,
# Nearest to there: every, in, some, still, librorum, all, only, and,
# Nearest to however: some, were, for, to, both, as, in, supranationalism,
# Nearest to these: prevalent, very, generational, larger, certain, sundanese, negatives, significantly,
# Nearest to most: in, and, many, as, kel, other, librorum, diverse,
# Nearest to states: united, nations, multilateral, nafta, federal, parliaments, asean, inauguration,
# Nearest to report: research, investigation, agency, employees, assessment, international, gov, review,
# Nearest to writers: novelists, autodidacts, poets, dramatists, satirists, polymaths, natives, londoners,
# Nearest to engineering: engineers, institute, technology, undergraduate, research, biomedical, aeronautics, sciences,
# Nearest to applications: desktop, openoffice, systems, mainframes, openvms, stored, networking, functionality,
# Nearest to placed: but, fist, finally, nose, instead, musket, reedy, knee,
# Nearest to articles: page, org, wikipedia, discussion, websites, forum, comprehensive, web,
# Nearest to numerous: influx, especially, metropolis, bujumbura, villages, lookout, fishing, majuro,
# Nearest to taking: lose, difficulty, own, hurting, beaten, upset, they, trying,
#
#
#
# Epoch 3/10 Iteration: 2000 Avg. Training loss: 0.4177 0.0140 sec/batch
# Nearest to zero: four, five, three, six, two, one, eight, nine,
# Nearest to over: total, all, years, challenges, expectancy, combined, rate, est,
# Nearest to six: five, four, three, eight, zero, two, one, seven,
# Nearest to there: every, for, are, other, only, some, is, given,
# Nearest to however: some, as, for, were, both, to, wicasa, in,
# Nearest to these: prevalent, certain, enunciated, very, negatives, generational, coerce, genealogists,
# Nearest to most: other, environments, prevalent, many, relationships, in, these, as,
# Nearest to states: united, nations, decolonization, nonproliferation, estados, nafta, organisations, department,
# Nearest to report: research, investigation, review, agency, gov, dod, assessment, international,
# Nearest to writers: novelists, autodidacts, poets, dramatists, satirists, polymaths, natives, londoners,
# Nearest to engineering: engineers, technology, undergraduate, institute, biomedical, university, professors, graduate,
# Nearest to applications: desktop, openoffice, openvms, microcoded, irix, workgroup, mainframes, recompilation,
# Nearest to placed: but, varnish, instead, finally, protect, mandibles, stasis, arrows,
# Nearest to articles: page, wikipedia, org, comprehensive, information, web, http, online,
# Nearest to numerous: shrinking, metropolis, majuro, especially, fishing, role, including, gunned,
# Nearest to taking: lose, beaten, missed, difficulty, got, twice, impeccable, once,
#
#
#
# Epoch 3/10 Iteration: 3000 Avg. Training loss: 0.4072 0.0143 sec/batch
# Nearest to zero: five, three, four, two, six, one, nine, eight,
# Nearest to over: total, years, est, expectancy, one, all, ratio, male,
# Nearest to six: five, four, two, three, eight, seven, one, zero,
# Nearest to there: every, are, is, all, only, for, given, sexagesimal,
# Nearest to however: as, were, some, for, the, in, to, both,
# Nearest to these: coerce, certain, very, redefinition, prevalent, generational, stresses, negatives,
# Nearest to most: other, and, relationships, prevalent, many, environments, ranging, comprise,
# Nearest to states: united, nations, nonproliferation, decolonization, member, estados, presidents, vouli,
# Nearest to report: research, review, investigation, dod, assessment, reports, agency, gov,
# Nearest to writers: novelists, autodidacts, satirists, poets, dramatists, natives, londoners, essayists,
# Nearest to engineering: engineers, technology, biomedical, undergraduate, institute, research, disciplines, aeronautics,
# Nearest to applications: openvms, openoffice, desktop, widgets, microcoded, optimized, mainframes, tools,
# Nearest to placed: soak, but, varnish, mandibles, fist, specially, fitted, finally,
# Nearest to articles: wikipedia, page, html, org, http, com, information, archive,
# Nearest to numerous: bujumbura, vlachs, role, spoiled, harshest, haudenosaunee, especially, majuro,
# Nearest to taking: lose, inmates, beaten, compromise, pacifistic, jail, difficulty, stepped,
#
#
#
# Epoch 3/10 Iteration: 4000 Avg. Training loss: 0.3981 0.0134 sec/batch
# Nearest to zero: five, four, two, three, six, one, nine, eight,
# Nearest to over: total, male, est, years, one, under, ratio, challenges,
# Nearest to six: five, four, two, one, seven, eight, three, zero,
# Nearest to there: are, all, every, is, from, some, given, commute,
# Nearest to however: were, as, in, rest, almost, for, to, the,
# Nearest to these: coerce, sundanese, prevalent, very, certain, amish, shanghainese, genealogists,
# Nearest to most: cultural, comprise, among, diverse, other, and, many, belong,
# Nearest to states: united, nations, trilateral, stimson, nonproliferation, federal, decolonization, estados,
# Nearest to report: reports, investigation, assessment, research, review, agency, approving, dossier,
# Nearest to writers: novelists, autodidacts, poets, essayists, dramatists, satirists, natives, londoners,
# Nearest to engineering: engineers, biomedical, technology, undergraduate, institute, aeronautics, research, disciplines,
# Nearest to applications: desktop, openvms, openoffice, microsoft, irix, microcoded, solaris, cygwin,
# Nearest to placed: crematoria, but, finally, instead, fist, hand, unprepared, bayonets,
# Nearest to articles: wikipedia, org, page, information, http, html, online, com,
# Nearest to numerous: vlachs, repopulated, majuro, including, bujumbura, lindo, rattlesnake, leveled,
# Nearest to taking: lose, inmates, authorising, pacifistic, hurting, difficulty, what, abuser,
# Epoch 3/10 Iteration: 4620 Avg. Training loss: 0.4104 0.0139 sec/batch
# Epoch 4/10 Iteration: 1000 Avg. Training loss: 0.4018 0.0128 sec/batch
# Nearest to zero: three, five, four, two, six, one, nine, eight,
# Nearest to over: total, challenges, all, under, years, ratio, est, sportsman,
# Nearest to six: five, four, eight, one, two, seven, three, zero,
# Nearest to there: every, are, some, those, all, from, have, for,
# Nearest to however: were, some, rest, for, halved, almost, supranationalism, both,
# Nearest to these: sundanese, prevalent, shanghainese, very, monochromacy, coerce, counterparts, axonal,
# Nearest to most: belong, for, comprise, kel, many, relationships, in, anthromorphic,
# Nearest to states: united, stimson, nations, america, trilateral, americans, unep, resident,
# Nearest to report: investigation, greenfacts, research, reports, assessment, retrieved, pdf, dod,
# Nearest to writers: novelists, autodidacts, poets, dramatists, londoners, essayists, satirists, natives,
# Nearest to engineering: engineers, biomedical, institute, aeronautics, technology, undergraduate, robotics, informatics,
# Nearest to applications: microcoded, desktop, openvms, cygwin, openoffice, staroffice, macromedia, decnet,
# Nearest to placed: fist, but, musket, specially, shoot, finally, shredded, cocking,
# Nearest to articles: wikipedia, org, page, websites, information, http, wikis, html,
# Nearest to numerous: spawned, majuro, shrinking, rivalled, including, especially, metropolis, repopulated,
# Nearest to taking: lose, difficulty, hospitalized, hurting, paranoid, beaten, abuser, appetites,
#
#
#
# Epoch 4/10 Iteration: 2000 Avg. Training loss: 0.3923 0.0140 sec/batch
# Nearest to zero: five, three, four, two, six, one, nine, eight,
# Nearest to over: total, challenges, all, years, male, ratio, fia, the,
# Nearest to six: five, four, eight, one, seven, three, two, zero,
# Nearest to there: every, are, given, for, is, sieves, exists, only,
# Nearest to however: as, both, for, rest, some, whereas, were, hechsher,
# Nearest to these: sundanese, prevalent, nameserver, most, certain, coerce, dura, syncretism,
# Nearest to most: many, comprise, for, are, these, differences, and, other,
# Nearest to states: united, nations, stimson, resident, ratify, unep, nonproliferation, decolonization,
# Nearest to report: research, greenfacts, dod, investigation, pdf, review, reports, gov,
# Nearest to writers: novelists, autodidacts, satirists, dramatists, essayists, screenwriters, illustrators, poets,
# Nearest to engineering: engineers, biomedical, professors, informatics, institute, undergraduate, aeronautics, graduate,
# Nearest to applications: irix, openvms, microcoded, cygwin, desktop, staroffice, multiprocessor, java,
# Nearest to placed: cocking, stasis, specially, choke, soak, geckos, pouch, but,
# Nearest to articles: wikipedia, wikis, org, page, information, slashdot, encyclopedias, businessweek,
# Nearest to numerous: majuro, shrinking, including, spawned, metropolis, stamping, rivalled, peculiarities,
# Nearest to taking: lose, beaten, speedweeks, inmates, appetites, impeccable, unsportsmanlike, gotten,
#
#
#
# Epoch 4/10 Iteration: 3000 Avg. Training loss: 0.3962 0.0139 sec/batch
# Nearest to zero: five, three, four, two, six, one, nine, eight,
# Nearest to over: total, all, years, challenges, one, male, of, the,
# Nearest to six: five, four, two, eight, seven, one, three, zero,
# Nearest to there: every, are, is, given, sieves, unsettled, all, have,
# Nearest to however: as, were, both, for, rest, the, some, pashtunistan,
# Nearest to these: shanghainese, rationalisation, prevalent, coerce, septuagint, dura, overkill, duplicated,
# Nearest to most: and, comprise, many, belong, arisen, denomination, differences, especially,
# Nearest to states: united, nations, nonproliferation, decolonization, act, kingdom, trilateral, aladi,
# Nearest to report: greenfacts, review, pdf, investigation, research, ipcc, dod, reports,
# Nearest to writers: novelists, autodidacts, illustrators, dramatists, satirists, londoners, essayists, screenwriters,
# Nearest to engineering: engineers, biomedical, informatics, professors, disciplines, aeronautics, undergraduate, institute,
# Nearest to applications: openvms, desktop, openoffice, irix, applets, cygwin, java, jscript,
# Nearest to placed: specially, pouch, fist, crematoria, soak, lengthening, pray, chopsticks,
# Nearest to articles: wikipedia, businessweek, slashdot, html, wikis, page, information, http,
# Nearest to numerous: majuro, including, spawned, part, spoiled, especially, vlachs, practised,
# Nearest to taking: appetites, inmates, sexualized, throats, lose, blemish, once, gotten,
#
#
#
# Epoch 4/10 Iteration: 4000 Avg. Training loss: 0.3755 0.0146 sec/batch
# Nearest to zero: five, four, two, three, six, one, nine, eight,
# Nearest to over: total, of, challenges, male, all, the, years, est,
# Nearest to six: five, four, eight, seven, two, one, zero, three,
# Nearest to there: are, every, is, all, exists, interquartile, those, enumerate,
# Nearest to however: were, for, as, rest, some, furthermore, the, both,
# Nearest to these: mishnaic, shanghainese, dura, rationalisation, sundanese, prevalent, duplicated, septuagint,
# Nearest to most: comprise, haitians, and, belong, denomination, many, ranging, arisen,
# Nearest to states: united, aladi, trilateral, act, stimson, nonproliferation, nations, goebel,
# Nearest to report: reports, ipcc, greenfacts, investigation, dossier, dod, https, unfccc,
# Nearest to writers: novelists, autodidacts, essayists, screenwriters, dramatists, illustrators, londoners, scientologists,
# Nearest to engineering: engineers, biomedical, informatics, aeronautics, undergraduate, management, professors, coursework,
# Nearest to applications: desktop, openvms, freedesktop, cygwin, openoffice, microsoft, applets, plugins,
# Nearest to placed: crematoria, specially, soak, pray, deshima, cedilla, narthex, lengthened,
# Nearest to articles: wikipedia, information, wikis, org, businessweek, article, page, html,
# Nearest to numerous: including, spawned, majuro, shrinking, leveled, part, rivalled, xmas,
# Nearest to taking: baghd, rapunzel, lose, quit, speedweeks, hurting, authorising, retraction,
#
#
#
# Epoch 4/10 Iteration: 4620 Avg. Training loss: 0.4019 0.0139 sec/batch
# Epoch 5/10 Iteration: 1000 Avg. Training loss: 0.3997 0.0148 sec/batch
# Nearest to zero: five, four, three, two, six, one, nine, eight,
# Nearest to over: challenges, total, all, under, years, of, the, a,
# Nearest to six: five, seven, four, one, eight, two, zero, three,
# Nearest to there: every, are, nilotic, those, missourians, easterners, some, valletta,
# Nearest to however: were, for, rest, as, stalled, some, halved, draftees,
# Nearest to these: prevalent, sundanese, mechs, duplicated, monochromacy, overkill, septuagint, dura,
# Nearest to most: many, belong, comprise, and, outnumber, for, these, haitians,
# Nearest to states: united, wabash, trilateral, kentucky, act, aladi, americans, nations,
# Nearest to report: greenfacts, ipcc, investigation, reports, retrieved, pdf, research, gov,
# Nearest to writers: novelists, autodidacts, essayists, dramatists, satirists, londoners, screenwriters, poets,
# Nearest to engineering: engineers, biomedical, aeronautics, informatics, professors, institute, robotics, dentistry,
# Nearest to applications: openvms, freedesktop, cygwin, java, applets, plugins, desktop, staroffice,
# Nearest to placed: specially, shredded, instantly, crematoria, pray, apron, ascended, soak,
# Nearest to articles: wikipedia, org, slashdot, businessweek, page, wikis, html, article,
# Nearest to numerous: including, spawned, part, rivalled, bujumbura, vitus, dahomey, leveled,
# Nearest to taking: sensitivities, beaten, hurting, garrisoned, lose, magistracies, inmates, rapunzel,
#
#
#
# Epoch 5/10 Iteration: 2000 Avg. Training loss: 0.3908 0.0134 sec/batch
# Nearest to zero: five, four, three, two, six, one, nine, eight,
# Nearest to over: total, challenges, the, all, a, of, bulk, and,
# Nearest to six: five, four, seven, eight, one, zero, two, three,
# Nearest to there: every, are, sieves, is, exists, those, sqrtn, given,
# Nearest to however: for, as, supranationalism, whereas, some, proportionally, its, were,
# Nearest to these: most, septuagint, mechs, factorize, sundanese, skew, over, dura,
# Nearest to most: many, and, these, comprise, as, denomination, for, a,
# Nearest to states: united, trilateral, act, kentucky, nominees, americans, kingdom, wabash,
# Nearest to report: greenfacts, ipcc, pdf, reports, gov, research, dod, investigation,
# Nearest to writers: novelists, autodidacts, essayists, dramatists, screenwriters, satirists, illustrators, humorists,
# Nearest to engineering: engineers, biomedical, robotics, dentistry, informatics, disciplines, professors, mechatronics,
# Nearest to applications: java, freedesktop, cygwin, openvms, applets, desktop, staroffice, irix,
# Nearest to placed: specially, instantly, soak, apron, stasis, protect, pouch, disassembled,
# Nearest to articles: wikipedia, businessweek, page, podcasting, wikis, org, encyclopedias, html,
# Nearest to numerous: spawned, including, rivalled, part, shrinking, xmas, role, metropolis,
# Nearest to taking: unsportsmanlike, beaten, baghd, garrisoned, quit, hurting, speedweeks, retorted,
# Epoch 5/10 Iteration: 3000 Avg. Training loss: 0.3918 0.0153 sec/batch
# Nearest to zero: five, four, three, two, six, nine, one, seven,
# Nearest to over: total, challenges, one, bulk, years, a, of, the,
# Nearest to six: five, seven, four, one, eight, two, zero, three,
# Nearest to there: are, every, sieves, is, exists, mor, syntactical, those,
# Nearest to however: for, furthermore, as, rest, until, proportionally, acceding, some,
# Nearest to these: skew, overkill, duplicated, become, mechs, other, among, most,
# Nearest to most: and, many, a, belong, for, ratites, comprise, in,
# Nearest to states: united, act, trilateral, ulmanis, aladi, america, americans, nations,
# Nearest to report: greenfacts, ipcc, pdf, reports, dod, retrieved, unfccc, dossier,
# Nearest to writers: novelists, autodidacts, essayists, screenwriters, satirists, dramatists, poets, illustrators,
# Nearest to engineering: engineers, biomedical, electrical, disciplines, informatics, dentistry, geotechnical, mechatronics,
# Nearest to applications: java, applets, freedesktop, openvms, cygwin, recompilation, bytecode, desktop,
# Nearest to placed: specially, soak, instantly, ligatures, pray, apron, pouch, flick,
# Nearest to articles: businessweek, wikipedia, encyclopedias, slashdot, page, podcasting, sourceforge, html,
# Nearest to numerous: role, part, including, spawned, rivalled, xmas, vitus, leveled,
# Nearest to taking: baghd, garrisoned, rapunzel, retorted, fortitude, gaugamela, blemish, lenthall,
#
#
#
# Epoch 5/10 Iteration: 4000 Avg. Training loss: 0.3706 0.0141 sec/batch
# Nearest to zero: five, four, two, three, six, one, nine, eight,
# Nearest to over: total, challenges, of, one, bulk, a, est, male,
# Nearest to six: five, four, seven, one, eight, zero, two, three,
# Nearest to there: are, every, is, extra, those, exists, sieves, interquartile,
# Nearest to however: for, furthermore, were, proportionally, as, rest, the, in,
# Nearest to these: sundanese, overkill, become, duplicated, mechs, other, among, combined,
# Nearest to most: and, a, comprise, in, many, although, among, outnumber,
# Nearest to states: united, act, trilateral, legally, kentucky, unconstitutional, aladi, authorizes,
# Nearest to report: ipcc, greenfacts, reports, afp, unfccc, dod, pdf, assessment,
# Nearest to writers: novelists, autodidacts, essayists, satirists, dramatists, illustrators, screenwriters, fiction,
# Nearest to engineering: engineers, biomedical, coursework, dentistry, aeronautics, exams, informatics, professors,
# Nearest to applications: openvms, cygwin, freedesktop, applets, java, microsoft, jscript, desktop,
# Nearest to placed: specially, soak, crematoria, uda, protect, ligatures, boxes, deemed,
# Nearest to articles: wikipedia, encyclopedias, businessweek, wikis, slashdot, page, article, kuro,
# Nearest to numerous: part, spawned, leveled, including, rivalled, vlachs, caymanians, livelihoods,
# Nearest to taking: garrisoned, baghd, speedweeks, reposition, nyt, retraction, quit, holdover,
#
#
#
# Epoch 5/10 Iteration: 4620 Avg. Training loss: 0.3951 0.0134 sec/batch
# Epoch 6/10 Iteration: 1000 Avg. Training loss: 0.3933 0.0149 sec/batch
# Nearest to zero: five, four, three, two, six, one, eight, seven,
# Nearest to over: total, challenges, a, one, once, all, years, bulk,
# Nearest to six: five, one, four, seven, eight, two, zero, three,
# Nearest to there: are, every, extra, those, valletta, easterners, interquartile, handfasting,
# Nearest to however: were, for, supranationalism, proportionally, furthermore, fraught, censuses, rest,
# Nearest to these: sundanese, duplicated, many, dura, overkill, skew, smaller, achromatopsia,
# Nearest to most: and, comprise, in, a, many, for, moa, very,
# Nearest to states: united, kentucky, wabash, trilateral, act, kingdom, estados, nominees,
# Nearest to report: greenfacts, ipcc, afp, reports, pdf, spaceflights, dod, retrieved,
# Nearest to writers: novelists, autodidacts, satirists, essayists, dramatists, screenwriters, humorists, playwrights,
# Nearest to engineering: engineers, biomedical, aeronautics, dentistry, professors, coursework, informatics, mechatronics,
# Nearest to applications: cygwin, applets, freedesktop, openvms, jscript, java, recompilation, desktop,
# Nearest to placed: specially, soak, wreath, choke, noses, bowmen, apron, crematoria,
# Nearest to articles: wikipedia, kuro, slashdot, businessweek, encyclopedias, page, philatelic, wikis,
# Nearest to numerous: including, part, spawned, rivalled, vitus, bujumbura, role, peculiarities,
# Nearest to taking: insomnia, sensitivities, relapse, hernia, beaten, painkillers, abuser, hospitalized,
#
#
#
# Epoch 6/10 Iteration: 2000 Avg. Training loss: 0.3771 0.0165 sec/batch
# Nearest to zero: five, three, four, six, two, one, nine, eight,
# Nearest to over: once, a, total, the, challenges, following, all, bulk,
# Nearest to six: five, one, four, seven, eight, zero, three, two,
# Nearest to there: are, every, extra, sieves, exists, other, is, those,
# Nearest to however: for, proportionally, furthermore, rest, its, were, both, until,
# Nearest to these: sundanese, among, most, duplicated, dura, over, such, of,
# Nearest to most: and, many, a, comprise, for, are, denomination, in,
# Nearest to states: united, kentucky, trilateral, nominees, kingdom, estados, act, america,
# Nearest to report: greenfacts, ipcc, afp, reports, dod, research, counterterrorism, unfccc,
# Nearest to writers: novelists, autodidacts, satirists, essayists, dramatists, humorists, screenwriters, illustrators,
# Nearest to engineering: engineers, biomedical, dentistry, informatics, aeronautics, accreditation, professors, coursework,
# Nearest to applications: openvms, applets, java, freedesktop, jscript, plugins, recompilation, transclusion,
# Nearest to placed: specially, soak, choke, phagspa, bolsters, stacking, deemed, letterboxers,
# Nearest to articles: wikipedia, encyclopedias, businessweek, sourceforge, kuro, org, collaboratively, gfdl,
# Nearest to numerous: including, role, rivalled, spawned, part, xmas, especially, inspired,
# Nearest to taking: sensitivities, speedweeks, nyt, beaten, quit, disheveled, blemish, retraction,
#
#
#
# Epoch 6/10 Iteration: 3000 Avg. Training loss: 0.3807 0.0155 sec/batch
# Nearest to zero: five, three, four, two, six, one, nine, eight,
# Nearest to over: total, challenges, one, a, the, years, bulk, following,
# Nearest to six: five, seven, four, one, eight, two, zero, three,
# Nearest to there: are, sieves, every, is, other, those, exists, mor,
# Nearest to however: the, furthermore, for, its, rest, were, in, fraught,
# Nearest to these: skew, rationalisation, other, become, among, such, of, overkill,
# Nearest to most: and, a, although, many, especially, comprise, among, are,
# Nearest to states: united, act, trilateral, kingdom, estados, america, nominees, ulmanis,
# Nearest to report: greenfacts, ipcc, reports, dod, unfccc, afp, counterterrorism, research,
# Nearest to writers: novelists, autodidacts, essayists, satirists, dramatists, screenwriters, humorists, poets,
# Nearest to engineering: engineers, biomedical, geotechnical, dentistry, disciplines, informatics, aeronautics, mechatronics,
# Nearest to applications: openvms, java, applets, oxide, jscript, namespaces, freedesktop, conductivity,
# Nearest to placed: specially, soak, ligatures, pinnacles, noses, wreath, stacking, phagspa,
# Nearest to articles: wikipedia, encyclopedias, gfdl, page, slashdot, kuro, businessweek, weblog,
# Nearest to numerous: role, part, including, livelihoods, especially, spawned, in, leveled,
# Nearest to taking: retraction, blemish, baghd, garrisoned, lebesgue, sensitivities, given, inmates,
#
#
#
# Epoch 6/10 Iteration: 4000 Avg. Training loss: 0.3633 0.0140 sec/batch
# Nearest to zero: five, four, two, three, six, one, eight, nine,
# Nearest to over: challenges, total, of, one, a, following, bulk, all,
# Nearest to six: five, four, seven, one, eight, zero, two, three,
# Nearest to there: are, every, those, extra, is, sieves, easterners, chimborazo,
# Nearest to however: the, furthermore, in, were, its, rest, for, adopt,
# Nearest to these: sundanese, overkill, that, rationalisation, coerce, such, other, become,
# Nearest to most: and, although, a, many, comprise, denomination, as, especially,
# Nearest to states: united, act, unconstitutional, trilateral, legally, marbury, nominees, aladi,
# Nearest to report: ipcc, greenfacts, reports, afp, unfccc, assessment, concluded, pullout,
# Nearest to writers: novelists, essayists, autodidacts, humorists, dramatists, screenwriters, satirists, fiction,
# Nearest to engineering: engineers, biomedical, informatics, dentistry, disciplines, coursework, aeronautics, geotechnical,
# Nearest to applications: openvms, java, namespaces, jscript, plugins, freedesktop, microsoft, servlet,
# Nearest to placed: specially, soak, ligatures, demosthenes, probed, stacking, choke, pinnacles,
# Nearest to articles: wikipedia, encyclopedias, article, businessweek, kuro, gfdl, page, online,
# Nearest to numerous: part, spawned, rivalled, including, especially, leveled, moravian, inspired,
# Nearest to taking: garrisoned, authorising, retraction, quit, beaten, speedweeks, labienus, likes,
# Epoch 6/10 Iteration: 4620 Avg. Training loss: 0.3893 0.0141 sec/batch
# Epoch 7/10 Iteration: 1000 Avg. Training loss: 0.3846 0.0135 sec/batch
# Nearest to zero: five, four, three, two, six, one, eight, seven,
# Nearest to over: challenges, total, a, once, all, the, bulk, one,
# Nearest to six: five, seven, one, four, eight, two, three, zero,
# Nearest to there: are, those, every, is, trace, other, animist, common,
# Nearest to however: for, were, its, until, furthermore, proportionally, the, fraught,
# Nearest to these: sundanese, smaller, skew, overkill, that, other, most, classified,
# Nearest to most: and, many, very, a, for, in, comprise, including,
# Nearest to states: united, wabash, america, kentucky, unconstitutional, americans, trilateral, act,
# Nearest to report: greenfacts, ipcc, afp, reports, spaceflights, unfccc, pdf, research,
# Nearest to writers: novelists, essayists, autodidacts, satirists, dramatists, humorists, fiction, screenwriters,
# Nearest to engineering: engineers, biomedical, geotechnical, aeronautics, dentistry, biotechnology, mechatronics, meng,
# Nearest to applications: openvms, namespaces, freedesktop, java, plugins, servlet, jscript, javaserver,
# Nearest to placed: specially, soak, ligatures, letterboxers, boxes, tolkowsky, wreath, choke,
# Nearest to articles: wikipedia, businessweek, slashdot, encyclopedias, gfdl, kuro, page, online,
# Nearest to numerous: rivalled, inspired, in, part, spawned, including, innovative, xmas,
# Nearest to taking: garrisoned, sensitivities, beaten, insomnia, painkillers, disheveled, relapse, preparations,
#
#
#
# Epoch 7/10 Iteration: 2000 Avg. Training loss: 0.3775 0.0135 sec/batch
# Nearest to zero: five, three, four, two, six, one, nine, eight,
# Nearest to over: challenges, the, total, a, once, all, bulk, of,
# Nearest to six: five, one, four, seven, eight, two, three, zero,
# Nearest to there: are, every, those, sieves, is, only, other, trace,
# Nearest to however: for, its, furthermore, the, proportionally, were, some, until,
# Nearest to these: sundanese, such, that, most, of, certain, other, smaller,
# Nearest to most: and, many, comprise, as, although, a, especially, for,
# Nearest to states: united, nominees, unconstitutional, america, kingdom, americans, kentucky, trilateral,
# Nearest to report: greenfacts, ipcc, afp, reports, research, unfccc, dod, pullout,
# Nearest to writers: novelists, essayists, autodidacts, dramatists, satirists, humorists, screenwriters, blacklist,
# Nearest to engineering: engineers, biomedical, disciplines, meng, geotechnical, dentistry, aeronautics, mechatronics,
# Nearest to applications: openvms, java, servlet, freedesktop, namespaces, conductivity, javaserver, plugins,
# Nearest to placed: specially, soak, letterboxers, probed, choke, stacking, nanoseconds, ligatures,
# Nearest to articles: wikipedia, gfdl, page, businessweek, slashdot, encyclopedias, podcasting, collaboratively,
# Nearest to numerous: inspired, xmas, role, cystic, part, rivalled, in, spawned,
# Nearest to taking: garrisoned, sensitivities, retraction, disheveled, beaten, as, quit, systm,
#
#
#
# Epoch 7/10 Iteration: 3000 Avg. Training loss: 0.3781 0.0149 sec/batch
# Nearest to zero: five, three, four, two, six, one, nine, eight,
# Nearest to over: challenges, a, one, total, the, once, all, of,
# Nearest to six: five, one, four, seven, eight, two, three, zero,
# Nearest to there: are, every, is, those, trace, only, sieves, all,
# Nearest to however: the, for, furthermore, were, until, its, proportionally, some,
# Nearest to these: such, become, smaller, that, can, other, among, certain,
# Nearest to most: and, especially, although, as, highly, ratites, a, many,
# Nearest to states: united, nominees, trilateral, america, kingdom, americans, act, authorizes,
# Nearest to report: greenfacts, ipcc, afp, unfccc, research, pdf, reports, dod,
# Nearest to writers: novelists, autodidacts, essayists, satirists, screenwriters, dramatists, humorists, blacklist,
# Nearest to engineering: engineers, biomedical, geotechnical, mechatronics, disciplines, bioinformatics, meng, dentistry,
# Nearest to applications: openvms, servlet, java, namespaces, freedesktop, jscript, conductivity, javaserver,
# Nearest to placed: specially, soak, ligatures, demosthenes, stacking, probed, noses, chagi,
# Nearest to articles: wikipedia, businessweek, encyclopedias, gfdl, page, kuro, nupedia, podcasting,
# Nearest to numerous: inspired, part, role, in, especially, the, collages, xmas,
# Nearest to taking: garrisoned, blemish, baghd, derg, retraction, magistracies, disheveled, forseti,
#
#
#
# Epoch 7/10 Iteration: 4000 Avg. Training loss: 0.3540 0.0149 sec/batch
# Nearest to zero: five, four, two, three, six, one, nine, seven,
# Nearest to over: challenges, one, total, of, a, bulk, the, facilitated,
# Nearest to six: five, four, one, seven, eight, two, zero, three,
# Nearest to there: are, every, is, extra, exists, trace, chimborazo, those,
# Nearest to however: the, for, furthermore, until, were, its, in, proportionally,
# Nearest to these: sundanese, such, can, become, notably, smaller, skew, other,
# Nearest to most: and, although, especially, a, highly, in, as, very,
# Nearest to states: united, kentucky, act, trilateral, nominees, americans, unconstitutional, legally,
# Nearest to report: ipcc, greenfacts, afp, reports, unfccc, research, politiken, pullout,
# Nearest to writers: novelists, essayists, autodidacts, satirists, dramatists, humorists, blacklist, screenwriters,
# Nearest to engineering: engineers, biomedical, aeronautics, bioinformatics, meng, geotechnical, disciplines, mechatronics,
# Nearest to applications: openvms, namespaces, java, javaserver, jscript, interbase, servlet, desktop,
# Nearest to placed: specially, demosthenes, soak, ligatures, stacking, uda, tipped, placement,
# Nearest to articles: wikipedia, encyclopedias, page, businessweek, kuro, nupedia, gfdl, article,
# Nearest to numerous: inspired, part, redacted, rivalled, vitus, including, vlachs, in,
# Nearest to taking: garrisoned, holdover, likes, turnovers, beaten, alamanni, culpable, speedweeks,
#
#
#
# Epoch 7/10 Iteration: 4620 Avg. Training loss: 0.3861 0.0150 sec/batch
# Epoch 8/10 Iteration: 1000 Avg. Training loss: 0.3795 0.0139 sec/batch
# Nearest to zero: five, three, four, two, six, one, nine, seven,
# Nearest to over: challenges, a, once, facilitated, total, following, one, of,
# Nearest to six: five, four, one, seven, two, eight, three, zero,
# Nearest to there: are, every, those, trace, is, exists, extra, other,
# Nearest to however: for, its, until, were, first, named, furthermore, widely,
# Nearest to these: smaller, such, other, classified, sundanese, skew, most, can,
# Nearest to most: many, very, and, marketable, comprise, as, especially, including,
# Nearest to states: united, kentucky, america, americans, nominees, kingdom, trilateral, maryland,
# Nearest to report: greenfacts, ipcc, afp, research, reports, unfccc, pdf, dod,
# Nearest to writers: novelists, autodidacts, satirists, essayists, dramatists, humorists, fiction, torontonians,
# Nearest to engineering: engineers, biomedical, biotechnology, meng, geotechnical, bioinformatics, dentistry, aeronautics,
# Nearest to applications: openvms, namespaces, freedesktop, staroffice, arsenide, conductivity, oxide, servlet,
# Nearest to placed: specially, soak, ligatures, probed, wreath, tipped, demosthenes, uda,
# Nearest to articles: wikipedia, page, kuro, slashdot, encyclopedias, gfdl, nupedia, online,
# Nearest to numerous: inspired, including, rivalled, in, bujumbura, vitus, innovative, influenced,
# Nearest to taking: garrisoned, painkillers, relapse, insomnia, beaten, disheveled, sensitivities, preparations,
#
#
#
# Epoch 8/10 Iteration: 2000 Avg. Training loss: 0.3843 0.0138 sec/batch
# Nearest to zero: five, three, four, two, six, one, nine, eight,
# Nearest to over: a, challenges, the, following, once, facilitated, one, of,
# Nearest to six: five, four, eight, one, seven, two, three, zero,
# Nearest to there: are, every, is, those, exists, trace, other, only,
# Nearest to however: for, widely, its, proportionally, the, until, wide, named,
# Nearest to these: such, most, can, classified, that, notably, other, smaller,
# Nearest to most: many, and, especially, these, marketable, as, differ, are,
# Nearest to states: united, nominees, kentucky, america, americans, kingdom, act, trilateral,
# Nearest to report: greenfacts, ipcc, afp, research, reports, dod, unfccc, expert,
# Nearest to writers: novelists, satirists, autodidacts, essayists, humorists, dramatists, fiction, torontonians,
# Nearest to engineering: engineers, biomedical, geotechnical, meng, biotechnology, aeronautics, microfluidics, disciplines,
# Nearest to applications: openvms, freedesktop, staroffice, cygwin, namespaces, servlet, applets, javaserver,
# Nearest to placed: specially, probed, choke, soak, letterboxers, muzzleloaders, ligatures, placement,
# Nearest to articles: wikipedia, page, encyclopedias, gfdl, wikis, kuro, online, nupedia,
# Nearest to numerous: inspired, including, influenced, role, in, iles, of, overarching,
# Nearest to taking: garrisoned, painkillers, insomnia, disheveled, conflicts, relapse, boniface, beaten,
# Epoch 8/10 Iteration: 3000 Avg. Training loss: 0.3769 0.0158 sec/batch
# Nearest to zero: five, three, four, two, six, one, nine, eight,
# Nearest to over: challenges, a, one, bulk, the, following, all, of,
# Nearest to six: five, four, seven, one, eight, two, zero, three,
# Nearest to there: are, every, is, trace, exists, those, extra, other,
# Nearest to however: for, the, widely, first, its, in, until, wide,
# Nearest to these: such, smaller, can, classified, other, over, become, by,
# Nearest to most: and, many, especially, very, as, differ, although, known,
# Nearest to states: united, nominees, americans, kentucky, america, trilateral, kingdom, estados,
# Nearest to report: greenfacts, ipcc, reports, afp, unfccc, research, dod, expert,
# Nearest to writers: novelists, essayists, autodidacts, satirists, humorists, dramatists, fiction, londoners,
# Nearest to engineering: engineers, biomedical, geotechnical, bioinformatics, biotechnology, disciplines, microfluidics, dentistry,
# Nearest to applications: openvms, staroffice, cygwin, applets, windows, freedesktop, microsoft, java,
# Nearest to placed: specially, ligatures, soak, wreath, placement, used, ceremony, indeterminate,
# Nearest to articles: page, wikipedia, gfdl, kuro, nupedia, encyclopedias, website, businessweek,
# Nearest to numerous: inspired, in, the, including, overarching, even, iles, role,
# Nearest to taking: garrisoned, magistracies, blemish, beaten, likes, disheveled, labienus, painkillers,
#
#
#
# Epoch 8/10 Iteration: 4000 Avg. Training loss: 0.3524 0.0133 sec/batch
# Nearest to zero: five, two, four, three, six, one, nine, eight,
# Nearest to over: challenges, one, a, of, facilitated, following, bulk, total,
# Nearest to six: five, four, seven, one, eight, two, zero, three,
# Nearest to there: are, extra, every, is, trace, those, exists, agree,
# Nearest to however: for, the, its, first, were, furthermore, widely, in,
# Nearest to these: such, can, classified, smaller, other, sundanese, well, blofeld,
# Nearest to most: and, as, differ, many, especially, very, ranging, somewhat,
# Nearest to states: united, nominees, kentucky, americans, legally, act, trilateral, presidential,
# Nearest to report: greenfacts, ipcc, reports, afp, unfccc, fnl, pullout, research,
# Nearest to writers: novelists, essayists, humorists, autodidacts, dramatists, fiction, satirists, academics,
# Nearest to engineering: engineers, biomedical, meng, biotechnology, geotechnical, bioinformatics, aeronautics, disciplines,
# Nearest to applications: staroffice, openvms, cygwin, windows, plugins, microsoft, servlet, namespaces,
# Nearest to placed: ligatures, specially, comb, demosthenes, placement, wreath, stacking, soak,
# Nearest to articles: wikipedia, encyclopedias, gfdl, page, kuro, wikis, article, nupedia,
# Nearest to numerous: inspired, including, redacted, influenced, have, part, even, in,
# Nearest to taking: garrisoned, likes, fractions, taken, dividing, magistracies, beaten, associations,
#
#
#
# Epoch 8/10 Iteration: 4620 Avg. Training loss: 0.3832 0.0157 sec/batch
# Epoch 9/10 Iteration: 1000 Avg. Training loss: 0.3714 0.0157 sec/batch
# Nearest to zero: five, four, three, two, six, one, seven, nine,
# Nearest to over: challenges, facilitated, a, one, bulk, following, total, once,
# Nearest to six: five, four, one, seven, eight, two, zero, three,
# Nearest to there: are, is, every, trace, those, common, exists, extra,
# Nearest to however: for, first, were, its, widely, until, the, named,
# Nearest to these: classified, such, smaller, other, can, well, are, that,
# Nearest to most: many, and, known, marketable, as, in, including, very,
# Nearest to states: united, americans, kentucky, america, nominees, maryland, wabash, legally,
# Nearest to report: greenfacts, ipcc, afp, reports, spaceflights, forcings, research, dod,
# Nearest to writers: novelists, humorists, essayists, autodidacts, satirists, dramatists, fiction, torontonians,
# Nearest to engineering: engineers, biomedical, biotechnology, meng, aeronautics, geotechnical, dentistry, aerospace,
# Nearest to applications: arsenide, openvms, plugins, cygwin, namespaces, conductivity, microphotonics, selenide,
# Nearest to placed: specially, wreath, muzzleloaders, probed, boxes, letterboxers, ligatures, pinnacles,
# Nearest to articles: wikipedia, page, kuro, encyclopedias, article, gfdl, wikis, nupedia,
# Nearest to numerous: in, inspired, including, have, influenced, rivalled, iles, been,
# Nearest to taking: painkillers, insomnia, sensitivities, likes, beaten, pde, fractions, garrisoned,
#
#
#
# Epoch 9/10 Iteration: 2000 Avg. Training loss: 0.3663 0.0144 sec/batch
# Nearest to zero: five, four, three, two, six, one, seven, nine,
# Nearest to over: a, challenges, the, facilitated, of, following, one, once,
# Nearest to six: five, four, one, seven, eight, two, zero, three,
# Nearest to there: are, every, is, exists, those, trace, only, extra,
# Nearest to however: for, widely, its, the, wide, first, were, until,
# Nearest to these: such, classified, can, well, other, that, differ, most,
# Nearest to most: many, and, as, especially, highly, for, known, including,
# Nearest to states: united, nominees, kentucky, americans, legally, america, trilateral, act,
# Nearest to report: greenfacts, ipcc, afp, reports, research, forcings, unfccc, pdf,
# Nearest to writers: novelists, humorists, essayists, autodidacts, satirists, dramatists, fiction, diarists,
# Nearest to engineering: engineers, biomedical, geotechnical, biotechnology, meng, aeronautics, aerospace, disciplines,
# Nearest to applications: openvms, arsenide, conductivity, microphotonics, tools, cmp, plugins, bandgap,
# Nearest to placed: specially, probed, soak, placement, protect, choke, foregrip, muzzleloaders,
# Nearest to articles: page, wikipedia, encyclopedias, gfdl, wikis, findable, article, dissertations,
# Nearest to numerous: inspired, including, in, influenced, even, iles, due, of,
# Nearest to taking: sensitivities, beaten, quit, pde, painkillers, administration, speedweeks, insomnia,
#
#
#
# Epoch 9/10 Iteration: 3000 Avg. Training loss: 0.3649 0.0132 sec/batch
# Nearest to zero: five, two, four, three, six, one, nine, seven,
# Nearest to over: a, one, challenges, of, the, facilitated, total, following,
# Nearest to six: five, four, one, seven, eight, two, zero, three,
# Nearest to there: are, every, is, trace, other, extra, but, exists,
# Nearest to however: the, widely, were, first, for, until, some, its,
# Nearest to these: classified, such, other, can, well, over, become, of,
# Nearest to most: and, many, especially, as, highly, although, largely, known,
# Nearest to states: united, nominees, americans, legally, trilateral, kentucky, america, act,
# Nearest to report: greenfacts, ipcc, reports, afp, expert, unfccc, forcings, pdf,
# Nearest to writers: novelists, essayists, humorists, autodidacts, satirists, dramatists, fiction, alumni,
# Nearest to engineering: engineers, geotechnical, biomedical, biotechnology, electrical, aeronautics, meng, bioinformatics,
# Nearest to applications: arsenide, conductivity, plugins, staroffice, bandgap, microphotonics, openvms, javaserver,
# Nearest to placed: specially, ligatures, probed, demosthenes, placement, protect, pinnacles, chopsticks,
# Nearest to articles: wikipedia, page, nupedia, encyclopedias, gfdl, article, wikis, kuro,
# Nearest to numerous: inspired, iles, the, in, even, of, influenced, rivalled,
# Nearest to taking: lebesgue, given, likes, garrisoned, stonewall, ways, boll, taken,
#
#
#
# Epoch 9/10 Iteration: 4000 Avg. Training loss: 0.3429 0.0139 sec/batch
# Nearest to zero: five, two, four, three, six, one, nine, seven,
# Nearest to over: a, challenges, one, of, facilitated, following, total, the,
# Nearest to six: five, four, one, seven, eight, zero, two, three,
# Nearest to there: are, is, every, trace, extra, chimborazo, other, exists,
# Nearest to however: the, were, first, widely, for, its, furthermore, in,
# Nearest to these: classified, such, well, notably, become, other, can, main,
# Nearest to most: many, and, especially, known, as, very, highly, including,
# Nearest to states: united, legally, nominees, kentucky, americans, marbury, act, congressional,
# Nearest to report: greenfacts, ipcc, reports, afp, unfccc, expert, panel, forcings,
# Nearest to writers: novelists, essayists, humorists, autodidacts, satirists, fiction, dramatists, alumni,
# Nearest to engineering: engineers, geotechnical, biomedical, biotechnology, aeronautics, bioinformatics, meng, electrical,
# Nearest to applications: staroffice, limewire, microsoft, windows, openvms, freedesktop, gtk, javaserver,
# Nearest to placed: specially, protect, placement, ligatures, demosthenes, chopsticks, family, lozenge,
# Nearest to articles: wikipedia, encyclopedias, page, article, ginzberg, org, dissertations, column,
# Nearest to numerous: inspired, even, redacted, including, iles, frequently, influenced, desecrated,
# Nearest to taking: likes, fractions, beaten, grammarians, fades, stonewall, invocations, garrisoned,
#
#
#
# Epoch 9/10 Iteration: 4620 Avg. Training loss: 0.3780 0.0135 sec/batch
# Epoch 10/10 Iteration: 1000 Avg. Training loss: 0.3696 0.0124 sec/batch
# Nearest to zero: five, two, three, four, six, one, nine, seven,
# Nearest to over: a, facilitated, challenges, one, of, the, following, total,
# Nearest to six: five, one, four, seven, eight, two, zero, three,
# Nearest to there: are, is, trace, those, every, common, exists, many,
# Nearest to however: first, were, for, widely, its, until, the, one,
# Nearest to these: classified, such, well, some, notably, can, smaller, are,
# Nearest to most: many, highly, and, as, although, very, known, in,
# Nearest to states: united, kentucky, nominees, americans, maryland, california, australasian, america,
# Nearest to report: greenfacts, ipcc, afp, reports, forcings, zubaydah, pullout, panel,
# Nearest to writers: novelists, humorists, essayists, satirists, dramatists, autodidacts, fiction, torontonians,
# Nearest to engineering: engineers, biomedical, geotechnical, biotechnology, aeronautics, meng, microfluidics, bioinformatics,
# Nearest to applications: bandgap, staroffice, arsenide, openvms, strontium, freedesktop, plugins, namespaces,
# Nearest to placed: specially, protect, wreath, in, letterboxers, muzzleloaders, revealed, tubing,
# Nearest to articles: page, nyt, online, ginzberg, org, article, column, stedman,
# Nearest to numerous: inspired, including, iles, santander, even, desecrated, rivalled, influenced,
# Nearest to taking: fractions, supplementation, ways, associations, beaten, accelerate, months, insomnia,
#
#
#
# Epoch 10/10 Iteration: 2000 Avg. Training loss: 0.3725 0.0131 sec/batch
# Nearest to zero: five, two, three, four, six, one, nine, seven,
# Nearest to over: a, the, challenges, of, following, all, facilitated, one,
# Nearest to six: five, one, eight, four, seven, zero, two, three,
# Nearest to there: are, is, every, trace, those, only, exists, extra,
# Nearest to however: widely, for, were, the, first, its, wide, until,
# Nearest to these: classified, well, such, most, can, notably, are, differ,
# Nearest to most: many, and, as, highly, especially, very, although, these,
# Nearest to states: united, nominees, kentucky, americans, america, legally, kingdom, york,
# Nearest to report: greenfacts, ipcc, forcings, reports, research, afp, expert, unfccc,
# Nearest to writers: novelists, essayists, humorists, satirists, autodidacts, dramatists, fiction, poets,
# Nearest to engineering: engineers, biomedical, geotechnical, microfluidics, biotechnology, aeronautics, meng, mechatronics,
# Nearest to applications: bandgap, plugins, staroffice, namespaces, strontium, arsenide, gorgias, ospf,
# Nearest to placed: specially, protect, used, choke, letterboxers, but, muzzleloaders, foregrip,
# Nearest to articles: online, page, encyclopedias, nyt, gfdl, article, dissertations, org,
# Nearest to numerous: inspired, including, desecrated, livelihoods, santander, even, iles, due,
# Nearest to taking: months, fades, burnt, fractions, odds, garrisoned, beaten, draconic,
#
#
#
# Epoch 10/10 Iteration: 3000 Avg. Training loss: 0.3604 0.0129 sec/batch
# Nearest to zero: five, two, four, three, six, nine, one, seven,
# Nearest to over: a, of, challenges, one, the, enabled, facilitated, following,
# Nearest to six: five, four, seven, one, eight, two, zero, three,
# Nearest to there: are, is, every, trace, but, for, exists, other,
# Nearest to however: the, widely, for, were, first, that, in, some,
# Nearest to these: such, classified, other, well, smaller, over, due, can,
# Nearest to most: many, and, as, especially, although, very, rare, highly,
# Nearest to states: united, nominees, americans, america, legally, kentucky, marshall, hawaii,
# Nearest to report: greenfacts, ipcc, reports, forcings, expert, biotechnology, research, afp,
# Nearest to writers: novelists, essayists, humorists, autodidacts, satirists, dramatists, poets, alumni,
# Nearest to engineering: engineers, geotechnical, biomedical, electrical, microfluidics, biotechnology, aeronautics, disciplines,
# Nearest to applications: staroffice, javaserver, arsenide, namespaces, plugins, thorium, strontium, openvms,
# Nearest to placed: specially, used, protect, fitted, wreath, ligatures, phalaris, comb,
# Nearest to articles: page, encyclopedias, article, wikipedia, online, portal, findable, gfdl,
# Nearest to numerous: in, inspired, even, including, of, the, iles, livelihoods,
# Nearest to taking: odds, garrisoned, burnt, months, beaten, stonewall, likes, given,
#
#
#
# Epoch 10/10 Iteration: 4000 Avg. Training loss: 0.3458 0.0127 sec/batch
# Nearest to zero: five, two, four, three, six, one, nine, seven,
# Nearest to over: of, one, challenges, a, facilitated, enabled, the, following,
# Nearest to six: five, four, one, seven, two, eight, zero, three,
# Nearest to there: are, is, trace, every, extra, chimborazo, exists, those,
# Nearest to however: were, first, the, widely, for, in, furthermore, until,
# Nearest to these: classified, well, such, notably, some, other, due, smaller,
# Nearest to most: many, and, as, especially, very, although, in, known,
# Nearest to states: united, nominees, legally, americans, kentucky, york, congressional, california,
# Nearest to report: greenfacts, reports, ipcc, afp, pullout, unfccc, zubaydah, forcings,
# Nearest to writers: novelists, essayists, humorists, autodidacts, satirists, alumni, dramatists, fiction,
# Nearest to engineering: engineers, geotechnical, biomedical, biotechnology, microfluidics, electrical, meng, aeronautics,
# Nearest to applications: staroffice, plugins, javaserver, namespaces, arsenide, abiword, ospf, gtk,
# Nearest to placed: specially, protect, fitted, comb, demosthenes, phalaris, designed, choke,
# Nearest to articles: wikipedia, article, portal, page, encyclopedias, nyt, column, online,
# Nearest to numerous: in, inspired, even, desecrated, redacted, including, spanned, frequently,
# Nearest to taking: associations, fractions, odds, garrisoned, ways, fades, beacons, exactly,
#
#
#
# Epoch 10/10 Iteration: 4620 Avg. Training loss: 0.3740 0.0134 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
